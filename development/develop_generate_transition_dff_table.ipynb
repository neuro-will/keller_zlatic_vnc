# %% [markdown]
# For developing and testing the function generate_transition_dff_table

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pathlib
import scipy.io

from keller_zlatic_vnc.data_processing import extract_transitions
from keller_zlatic_vnc.data_processing import generate_transition_dff_table
from keller_zlatic_vnc.data_processing import read_raw_transitions_from_excel
from keller_zlatic_vnc.data_processing import recode_beh
# Out:
# /Users/williambishop/Documents/Janelia_Research/Projects/janelia_core/janelia_core/fileio/exp_reader.py:21: UserWarning: Unable to locate pyklb module.  Will not be able to read in .klb files.
#   warnings.warn('Unable to locate pyklb module.  Will not be able to read in .klb files.')

# %% [markdown]
# ## Parameters go here

# %%
data_folder = r'/Volumes/bishoplab/projects/keller_vnc/data/extracted_dff_v2'
transition_file = 'transition_list.xlsx'

a4_act_data_file = 'A00c_activity_A4.mat'
a9_act_data_file = 'A00c_activity_A9.mat'

# %% [markdown]
# ## Load the data as provided by Chen

# %%
raw_trans = read_raw_transitions_from_excel(pathlib.Path(data_folder) / transition_file)

# %% [markdown]
# ## Recode the behavior to use standard abbreviations

# %%
raw_trans = recode_beh(raw_trans, 'Beh Before')
raw_trans = recode_beh(raw_trans, 'Beh After')

# %% [markdown]
# ## Extract transitions

# %%
trans = extract_transitions(raw_trans, np.inf)

# %% [markdown]
# ## Load the $\Delta F / F$ data

# %%
a4_act = scipy.io.loadmat(pathlib.Path(data_folder) / a4_act_data_file, squeeze_me=True)
a9_act = scipy.io.loadmat(pathlib.Path(data_folder) / a9_act_data_file, squeeze_me=True)

# %% [markdown]
# ## Generate the table

# %%
table = generate_transition_dff_table(act_data=a4_act, trans=trans)

# %%
table[table['subject_id'] == 'CW_17-08-23-L2']
# Out:
#         subject_id  cell_id event_id beh_before beh_after  dff_before  \
# 12  CW_17-08-23-L2      1.0        0          F         B    0.011937
# 13  CW_17-08-23-L2      1.0        1          F         B    0.016912
# 14  CW_17-08-23-L2      1.0        2          F         B    0.011312
# 15  CW_17-08-23-L2      2.0        0          F         B    0.003568
# 16  CW_17-08-23-L2      2.0        1          F         B    0.001162
# 17  CW_17-08-23-L2      2.0        2          F         B    0.016246
# 18  CW_17-08-23-L2      3.0        0          F         B   -0.032607
# 19  CW_17-08-23-L2      3.0        1          F         B    0.021043
# 20  CW_17-08-23-L2      3.0        2          F         B    0.017797
# 21  CW_17-08-23-L2      4.0        0          F         B   -0.026724
# 22  CW_17-08-23-L2      4.0        1          F         B    0.021342
# 23  CW_17-08-23-L2      4.0        2          F         B   -0.001356
# 24  CW_17-08-23-L2      5.0        0          F         B   -0.012109
# 25  CW_17-08-23-L2      5.0        1          F         B    0.004888
# 26  CW_17-08-23-L2      5.0        2          F         B    0.013958
# 27  CW_17-08-23-L2      6.0        0          F         B   -0.016382
# 28  CW_17-08-23-L2      6.0        1          F         B   -0.003311
# 29  CW_17-08-23-L2      6.0        2          F         B    0.010295
#
#     dff_during  dff_after
# 12    0.523572   0.836265
# 13    0.530245   0.719404
# 14    0.515213   0.698007
# 15    0.685494   1.146922
# 16    0.622618   1.017802
# 17    0.549792   0.840774
# 18    0.290360   0.632305
# 19    0.298244   0.536082
# 20    0.248266   0.433819
# 21    0.464759   0.995490
# 22    0.414374   0.858185
# 23    0.383946   0.763710
# 24    0.119600   0.252695
# 25    0.102265   0.210662
# 26    0.084881   0.132948
# 27    0.168853   0.369814
# 28    0.120592   0.230757
# 29    0.079723   0.148626

# %%
trans
# Out:
# {'CW_17-08-23-L1': [('F', 'P'), ('F', 'P')],
#  'CW_17-08-23-L2': [('F', 'B'), ('F', 'B'), ('F', 'B')],
#  'CW_17-08-23-L4': [('Q', 'F'),
#   ('Q', 'H'),
#   ('Q', 'Q'),
#   ('Q', 'H'),
#   ('Q', 'O'),
#   ('Q', 'Q')],
#  'CW_17-08-24-L1': [('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'P'),
#   ('Q', 'F'),
#   ('Q', 'H'),
#   ('Q', 'O'),
#   ('Q', 'F'),
#   ('Q', 'Q')],
#  'CW_17-08-24-L2-1': [('B', 'F')],
#  'CW_17-08-24-L2-2': [('Q', 'F'), ('Q', 'F'), ('Q', 'F'), ('Q', 'F')],
#  'CW_17-08-24-L4': [('O', 'B'),
#   ('B', 'F'),
#   ('T', 'B'),
#   ('T', 'B'),
#   ('T', 'T'),
#   ('B', 'B')],
#  'CW_17-08-24-L5': [('T', 'F'), ('B', 'F'), ('T', 'F')],
#  'CW_17-08-26-L1': [('F', 'F')],
#  'CW_17-08-26-L2': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F')],
#  'CW_17-08-26-L4': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F')],
#  'CW_17-08-26-L5': [('B', 'F'), ('B', 'F')],
#  'CW_17-08-26-L6': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'Q'),
#   ('Q', 'B'),
#   ('Q', 'O'),
#   ('Q', 'Q'),
#   ('Q', 'B'),
#   ('Q', 'F')],
#  'CW_17-08-27-L1': [('B', 'P'), ('T', 'B')],
#  'CW_17-08-27-L2': [('T', 'F'), ('T', 'F'), ('T', 'F')],
#  'CW_17-08-27-L3': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F')],
#  'CW_17-08-27-L4': [('O', 'F')],
#  'CW_17-08-27-L5': [('B', 'F'),
#   ('B', 'F'),
#   ('B', 'T'),
#   ('T', 'F'),
#   ('B', 'H'),
#   ('O', 'F')],
#  'CW_17-08-28-L1': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F')],
#  'CW_17-08-28-L2': [('F', 'F'), ('B', 'F'), ('F', 'F'), ('F', 'F')],
#  'CW_17-08-28-L3': [('B', 'F'), ('B', 'F'), ('B', 'T')],
#  'CW_17-08-29-L2': [('F', 'F')],
#  'CW_17-08-31-L1': [('F', 'P'), ('F', 'O'), ('F', 'P')],
#  'CW_17-09-01-L1': [('B', 'F'), ('B', 'F')],
#  'CW_17-09-01-L2': [('B', 'O')],
#  'CW_17-11-02-L3': [('B', 'T'), ('P', 'P'), ('F', 'F'), ('F', 'P')],
#  'CW_17-11-03-L1': [('F', 'F'), ('F', 'F'), ('F', 'F')],
#  'CW_17-11-03-L2': [('F', 'P'),
#   ('F', 'P'),
#   ('F', 'P'),
#   ('F', 'P'),
#   ('F', 'P')],
#  'CW_17-11-03-L3': [('F', 'P'), ('T', 'P'), ('F', 'F')],
#  'CW_17-11-03-L6': [('Q', 'O'), ('Q', 'Q'), ('Q', 'F')],
#  'CW_17-11-04-L1': [('F', 'P'),
#   ('F', 'O'),
#   ('F', 'P'),
#   ('F', 'P'),
#   ('F', 'P'),
#   ('Q', 'Q'),
#   ('Q', 'F'),
#   ('Q', 'F')],
#  'CW_17-11-04-L2': [('B', 'P')],
#  'CW_17-11-04-L3': [('B', 'F')],
#  'CW_17-11-04-L4': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'Q'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'Q'),
#   ('Q', 'F')],
#  'CW_17-11-06-L2': [('T', 'F')],
#  'CW_17-11-07-L2': [('T', 'F')],
#  'CW_17-11-07-L4': [('T', 'P'), ('B', 'T'), ('B', 'P')],
#  'CW_17-11-07-L5': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F')],
#  'CW_17-11-08-L1': [('B', 'F'), ('B', 'F'), ('B', 'F')],
#  'CW_17-11-08-L2': [('T', 'T'), ('F', 'P'), ('T', 'P'), ('F', 'P')],
#  'CW_17-11-08-L3': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'P'),
#   ('Q', 'F')],
#  'CW_17-11-26-L1': [('F', 'F'), ('F', 'F'), ('F', 'F')],
#  'CW_17-11-26-L2': [('B', 'T'), ('B', 'B'), ('B', 'T')],
#  'CW_17-11-26-L3': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'P'),
#   ('F', 'T'),
#   ('F', 'T'),
#   ('H', 'F')],
#  'CW_17-11-26-L4': [('B', 'F'), ('B', 'F')],
#  'CW_17-11-26-L5': [('Q', 'O'),
#   ('Q', 'F'),
#   ('Q', 'Q'),
#   ('Q', 'F'),
#   ('Q', 'Q'),
#   ('Q', 'Q'),
#   ('Q', 'H'),
#   ('Q', 'Q')],
#  'CW_17-11-27-L1': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'O'),
#   ('Q', 'F'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'F'),
#   ('Q', 'F')],
#  'CW_17-11-27-L2': [('B', 'H'), ('T', 'H')],
#  'CW_17-11-27-L3': [('O', 'F'), ('T', 'F')],
#  'CW_17-11-27-L4': [('Q', 'F'), ('B', 'F')],
#  'CW_17-11-27-L5': [('B', 'T'), ('T', 'P')],
#  'CW_17-11-28-L2': [('Q', 'Q'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'F'),
#   ('Q', 'O'),
#   ('Q', 'O')],
#  'CW_17-11-28-L3': [('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O')],
#  'CW_17-11-28-L4': [('F', 'F'), ('T', 'F'), ('O', 'F'), ('T', 'F')],
#  'CW_17-11-28-L6': [('B', 'F'), ('B', 'F'), ('B', 'F')],
#  'CW_17-11-29-L1': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F')],
#  'CW_17-11-29-L2': [('B', 'F')],
#  'CW_17-11-29-L3': [('B', 'F')],
#  'CW_17-11-29-L4': [('B', 'F')],
#  'CW_17-11-29-L5': [('B', 'B'), ('B', 'B'), ('T', 'B'), ('B', 'B')],
#  'CW_17-11-29-L6': [('T', 'F'), ('T', 'B'), ('B', 'B'), ('B', 'B')],
#  'CW_17-11-30-L2': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F')],
#  'CW_17-11-30-L3': [('Q', 'H'),
#   ('Q', 'Q'),
#   ('Q', 'T'),
#   ('Q', 'Q'),
#   ('Q', 'T'),
#   ('Q', 'Q'),
#   ('Q', 'H'),
#   ('Q', 'Q')],
#  'CW_17-12-11-L2': [('Q', 'F'), ('Q', 'Q'), ('Q', 'F'), ('Q', 'Q')],
#  'CW_17-12-11-L3': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F')]}

# %%
a4_act['activityPreManipulationSet'][1]
# Out:
# array([[ 1.00000000e+00,  1.19367154e-02,  1.69120309e-02,
#          1.13119925e-02],
#        [ 2.00000000e+00,  3.56770432e-03,  1.16241646e-03,
#          1.62461176e-02],
#        [ 3.00000000e+00, -3.26066552e-02,  2.10432783e-02,
#          1.77974896e-02],
#        [ 4.00000000e+00, -2.67236573e-02,  2.13419727e-02,
#         -1.35550519e-03],
#        [ 5.00000000e+00, -1.21087160e-02,  4.88822070e-03,
#          1.39580665e-02],
#        [ 6.00000000e+00, -1.63822526e-02, -3.31077050e-03,
#          1.02948875e-02]])

# %%
trans
# Out:
# {'CW_17-08-23-L1': [('F', 'P'), ('F', 'P')],
#  'CW_17-08-23-L2': [('F', 'B'), ('F', 'B'), ('F', 'B')],
#  'CW_17-08-23-L4': [('Q', 'F'),
#   ('Q', 'H'),
#   ('Q', 'Q'),
#   ('Q', 'H'),
#   ('Q', 'O'),
#   ('Q', 'Q')],
#  'CW_17-08-24-L1': [('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'P'),
#   ('Q', 'F'),
#   ('Q', 'H'),
#   ('Q', 'O'),
#   ('Q', 'F'),
#   ('Q', 'Q')],
#  'CW_17-08-24-L2-1': [('B', 'F')],
#  'CW_17-08-24-L2-2': [('Q', 'F'), ('Q', 'F'), ('Q', 'F'), ('Q', 'F')],
#  'CW_17-08-24-L4': [('O', 'B'),
#   ('B', 'F'),
#   ('T', 'B'),
#   ('T', 'B'),
#   ('T', 'T'),
#   ('B', 'B')],
#  'CW_17-08-24-L5': [('T', 'F'), ('B', 'F'), ('T', 'F')],
#  'CW_17-08-26-L1': [('F', 'F')],
#  'CW_17-08-26-L2': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F')],
#  'CW_17-08-26-L4': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F')],
#  'CW_17-08-26-L5': [('B', 'F'), ('B', 'F')],
#  'CW_17-08-26-L6': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'Q'),
#   ('Q', 'B'),
#   ('Q', 'O'),
#   ('Q', 'Q'),
#   ('Q', 'B'),
#   ('Q', 'F')],
#  'CW_17-08-27-L1': [('B', 'P'), ('T', 'B')],
#  'CW_17-08-27-L2': [('T', 'F'), ('T', 'F'), ('T', 'F')],
#  'CW_17-08-27-L3': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F')],
#  'CW_17-08-27-L4': [('O', 'F')],
#  'CW_17-08-27-L5': [('B', 'F'),
#   ('B', 'F'),
#   ('B', 'T'),
#   ('T', 'F'),
#   ('B', 'H'),
#   ('O', 'F')],
#  'CW_17-08-28-L1': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F')],
#  'CW_17-08-28-L2': [('F', 'F'), ('B', 'F'), ('F', 'F'), ('F', 'F')],
#  'CW_17-08-28-L3': [('B', 'F'), ('B', 'F'), ('B', 'T')],
#  'CW_17-08-29-L2': [('F', 'F')],
#  'CW_17-08-31-L1': [('F', 'P'), ('F', 'O'), ('F', 'P')],
#  'CW_17-09-01-L1': [('B', 'F'), ('B', 'F')],
#  'CW_17-09-01-L2': [('B', 'O')],
#  'CW_17-11-02-L3': [('B', 'T'), ('P', 'P'), ('F', 'F'), ('F', 'P')],
#  'CW_17-11-03-L1': [('F', 'F'), ('F', 'F'), ('F', 'F')],
#  'CW_17-11-03-L2': [('F', 'P'),
#   ('F', 'P'),
#   ('F', 'P'),
#   ('F', 'P'),
#   ('F', 'P')],
#  'CW_17-11-03-L3': [('F', 'P'), ('T', 'P'), ('F', 'F')],
#  'CW_17-11-03-L6': [('Q', 'O'), ('Q', 'Q'), ('Q', 'F')],
#  'CW_17-11-04-L1': [('F', 'P'),
#   ('F', 'O'),
#   ('F', 'P'),
#   ('F', 'P'),
#   ('F', 'P'),
#   ('Q', 'Q'),
#   ('Q', 'F'),
#   ('Q', 'F')],
#  'CW_17-11-04-L2': [('B', 'P')],
#  'CW_17-11-04-L3': [('B', 'F')],
#  'CW_17-11-04-L4': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'Q'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'Q'),
#   ('Q', 'F')],
#  'CW_17-11-06-L2': [('T', 'F')],
#  'CW_17-11-07-L2': [('T', 'F')],
#  'CW_17-11-07-L4': [('T', 'P'), ('B', 'T'), ('B', 'P')],
#  'CW_17-11-07-L5': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F')],
#  'CW_17-11-08-L1': [('B', 'F'), ('B', 'F'), ('B', 'F')],
#  'CW_17-11-08-L2': [('T', 'T'), ('F', 'P'), ('T', 'P'), ('F', 'P')],
#  'CW_17-11-08-L3': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'P'),
#   ('Q', 'F')],
#  'CW_17-11-26-L1': [('F', 'F'), ('F', 'F'), ('F', 'F')],
#  'CW_17-11-26-L2': [('B', 'T'), ('B', 'B'), ('B', 'T')],
#  'CW_17-11-26-L3': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'P'),
#   ('F', 'T'),
#   ('F', 'T'),
#   ('H', 'F')],
#  'CW_17-11-26-L4': [('B', 'F'), ('B', 'F')],
#  'CW_17-11-26-L5': [('Q', 'O'),
#   ('Q', 'F'),
#   ('Q', 'Q'),
#   ('Q', 'F'),
#   ('Q', 'Q'),
#   ('Q', 'Q'),
#   ('Q', 'H'),
#   ('Q', 'Q')],
#  'CW_17-11-27-L1': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'O'),
#   ('Q', 'F'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'F'),
#   ('Q', 'F')],
#  'CW_17-11-27-L2': [('B', 'H'), ('T', 'H')],
#  'CW_17-11-27-L3': [('O', 'F'), ('T', 'F')],
#  'CW_17-11-27-L4': [('Q', 'F'), ('B', 'F')],
#  'CW_17-11-27-L5': [('B', 'T'), ('T', 'P')],
#  'CW_17-11-28-L2': [('Q', 'Q'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'F'),
#   ('Q', 'O'),
#   ('Q', 'O')],
#  'CW_17-11-28-L3': [('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O'),
#   ('Q', 'O')],
#  'CW_17-11-28-L4': [('F', 'F'), ('T', 'F'), ('O', 'F'), ('T', 'F')],
#  'CW_17-11-28-L6': [('B', 'F'), ('B', 'F'), ('B', 'F')],
#  'CW_17-11-29-L1': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F')],
#  'CW_17-11-29-L2': [('B', 'F')],
#  'CW_17-11-29-L3': [('B', 'F')],
#  'CW_17-11-29-L4': [('B', 'F')],
#  'CW_17-11-29-L5': [('B', 'B'), ('B', 'B'), ('T', 'B'), ('B', 'B')],
#  'CW_17-11-29-L6': [('T', 'F'), ('T', 'B'), ('B', 'B'), ('B', 'B')],
#  'CW_17-11-30-L2': [('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F'),
#   ('F', 'F')],
#  'CW_17-11-30-L3': [('Q', 'H'),
#   ('Q', 'Q'),
#   ('Q', 'T'),
#   ('Q', 'Q'),
#   ('Q', 'T'),
#   ('Q', 'Q'),
#   ('Q', 'H'),
#   ('Q', 'Q')],
#  'CW_17-12-11-L2': [('Q', 'F'), ('Q', 'Q'), ('Q', 'F'), ('Q', 'Q')],
#  'CW_17-12-11-L3': [('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F'),
#   ('Q', 'F')]}
