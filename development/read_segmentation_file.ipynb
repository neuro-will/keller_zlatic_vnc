# %% [markdown]
# A notebook for testing how to read in segmentation data provided by Andrew

# %%
import matplotlib.pyplot as plt
import numpy as np

import pyklb
import tifffile

from keller_zlatic_vnc.raw_data_processing import generate_rois_from_segments

# %% [markdown]
# ## Parameters go here

# %%
# File holding segmentation data
seg_file = r'A:\projects\keller_vnc\data\segmentations\1099-20220126-sv_label_vox_corr_100_3000_SIZE_4_17_17_maxclust_5000_argmax.tiff'

# In example image of the specimen
im_file = r'W:\SV4\CW_18-02-15\L1-561nm-openLoop_20180215_163233.corrected\Results\WeightFused\TM000000\SPM00_TM000000_CM00_CM01_CHN00.weightFused.TimeRegistration.klb'

# %%
seg_image = tifffile.imread(seg_file)

# %%
rois = generate_rois_from_segments(seg_image)

# %%
roi_ind = 1
print(rois[roi_ind].seg_id)
seg_image[rois[roi_ind].voxel_inds]

# %% [markdown]
# ## Load a raw image

# %%
raw_image = pyklb.readfull(im_file)

# %% [markdown]
# ## Visualize raw image and segmentation image - just to make sure they overlap

# %%
vis_z = 10

# %%
plt.figure()
ax = plt.subplot(1,2,1)
ax.imshow(raw_image[vis_z,:,:])
ax = plt.subplot(1,2,2)
ax.imshow(seg_image[vis_z,:,:])

# %%
raw_image.shape
# Out:
# (80, 585, 369)

# %%
seg_image.shape
# Out:
# (80, 585, 369)
